# %%
import numpy as np
from pylab import *

# %matplotlib notebook

# %%
vela = np.load('data/SB40678/vela/short/vela-debughdr-card1-lsb11-dp.npy')

# %%
vela.dtype
# Out:
# dtype([('frame_id', '<u8'), ('bat', '<u8'), ('beam_number', 'u1'), ('sample_number', 'u1'), ('channel_number', 'u1'), ('fpga_id', 'u1'), ('nprod', '<u2'), ('flags', 'u1'), ('zero1', 'u1'), ('version', '<u4'), ('zero3', '<u4'), ('data', '<i2', (1, 465, 2, 2))])

# %%
vela.shape
# Out:
# (27944,)

# %%
figure()
plot(vela['beam_number'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
vela[0]
# Out:
# (147060736, 490528665635, 0, 0, 0, 0, 930, 4, 0, 2004071455, 0, [[[[ 14012,      0], [ 20619,      0]], [[   349,   -719], [  -350,   -728]], [[ -2366,    953], [ -1180,  -2136]], [[  -618,  -1915], [   269,    -44]], [[   368,   -346], [     0,      0]], [[ -1602,   -494], [     0,      0]], [[  2880,   1628], [     0,      0]], [[ -1659,   1014], [     0,      0]], [[ -2130,   1691], [     0,      0]], [[  1293,   -665], [   309,    619]], [[  4093,  -1278], [ -2276,   -109]], [[  -222,  -3701], [  -742,   2519]], [[    -5,   1808], [  -131,   -593]], [[  2827,   1806], [  -322,    196]], [[ -2097,   -757], [ -1428,   -735]], [[  1629,   -908], [    -5,  -2852]], [[ -2776,    178], [  1346,  -1035]], [[ -2810,   -683], [   -21,  -2419]], [[  -859,   -515], [   607,  -2442]], [[  -593,    806], [  -932,  -1740]], [[   292,   2351], [  -887,    153]], [[  1047,   -390], [  -337,   1122]], [[  1438,   3632], [  -545,    431]], [[   301,   1520], [  1614,    -82]], [[  -150,  -1230], [  -310,     44]], [[ -3180,   2087], [  -613,  -3169]], [[  2094,   -570], [  -611,  -1507]], [[ -1182,    628], [   -27,  -1222]], [[   972,   2184], [ -2587,    455]], [[  -229,  -1963], [  -660,  -1404]], [[ 19171,      0], [ 20923,      0]], [[   311,  -1850], [   899,   -579]], [[  1611,    862], [   401,   1294]], [[  -832,  -1160], [   169,   -464]], [[     0,      0], [ -1699,  -2198]], [[     0,      0], [ -3106,   -375]], [[     0,      0], [   165,    163]], [[     0,      0], [   912,   3453]], [[  -961,  -3217], [  -417,    872]], [[  -649,  -1452], [ -3449,   -526]], [[  2203,  -1684], [  -756,   4619]], [[ -1021,    466], [  -105,   1742]], [[  -445,   -779], [  -478,   1230]], [[ -3549,  -3676], [  1419,  -1872]], [[  -190,  -3134], [  -925,    178]], [[ -1274,   1795], [  1108,   -564]], [[  -277,   -435], [  3209,  -2578]], [[  2904,   -405], [  2429,   2350]], [[  -257,    498], [  1091,  -2309]], [[ -2083,    678], [ -1174,   -140]], [[ -2520,  -1477], [   -52,  -1213]], [[  -411,    482], [  -267,   1165]], [[ -2156,  -1858], [   539,   2905]], [[   277,  -1032], [  -557,   -820]], [[  -178,   1011], [  1716,  -1531]], [[ -1332,  -1841], [   134,   -105]], [[  2450,   -676], [ -2185,   1141]], [[   783,   -867], [ -1528,   1619]], [[  -476,     50], [  1441,    607]], [[ 17569,      0], [ 17786,      0]], [[   890,   1371], [  1781,   2898]], [[  1688,   2242], [  1018,   -689]], [[ -2450,  -2461], [  3081,   -427]], [[  -214,   1111], [ -1699,    131]], [[   370,   -149], [  1232,  -3456]], [[ -1341,   -100], [  -924,  -1038]], [[ -1596,    634], [  2389,   1755]], [[   361,    316], [  1714,  -1931]], [[   963,   -182], [  -985,  -2303]], [[  -127,   3118], [  -686,  -1281]], [[  1198,    471], [  1412,    -55]], [[   273,   1927], [  4829,   2755]], [[   -56,   1819], [    12,    153]], [[   -78,    139], [   207,    347]], [[  1056,    247], [   249,   1715]], [[ -2373,   -883], [  2735,   1279]], [[  -896,   1019], [  -994,   3021]], [[  -382,    816], [   -61,   1037]], [[   225,   1145], [ -1114,   2095]], [[ -3742,   -852], [  -672,    616]], [[ -2889,   4448], [  2621,   2043]], [[ -2194,    201], [   857,   -201]], [[  1510,   -924], [  -593,   1279]], [[   809,  -1570], [   777,   -824]], [[   785,    209], [  1380,  -1906]], [[   659,   1917], [   401,    917]], [[  -298,   -965], [ -1730,   -246]], [[ 22261,      0], [ 19729,      0]], [[   450,  -1159], [  1134,  -1692]], [[  1221,    487], [ -1084,  -1364]], [[   587,  -1278], [  1450,    166]], [[ -1005,   -747], [ -1652,  -2405]], [[   448,    681], [  1440,  -1137]], [[   127,    467], [   153,   1296]], [[  -919,  -1278], [   -86,   -140]], [[   471,   1519], [   194,    -12]], [[  2387,  -1804], [ -2044,  -1492]], [[ -2864,  -2191], [ -1228,   -336]], [[  -788,    527], [  3039,  -2207]], [[   270,  -3906], [ -2515,   -443]], [[   864,  -1964], [   415,   -249]], [[   511,    -42], [  -527,   -367]], [[    19,   2928], [  1476,   1103]], [[  -349,  -2338], [ ...

# %%
vela.dtype
# Out:
# dtype([('frame_id', '<u8'), ('bat', '<u8'), ('beam_number', 'u1'), ('sample_number', 'u1'), ('channel_number', 'u1'), ('fpga_id', 'u1'), ('nprod', '<u2'), ('flags', 'u1'), ('zero1', 'u1'), ('version', '<u4'), ('zero3', '<u4'), ('data', '<i2', (1, 465, 2, 2))])

# %%
vela['beam_number']
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=uint8)

# %%
b0 = vela[vela['beam_number'] == 0]

# %%
b0.shape
# Out:
# (832,)

# %%
figure()
plot(b0['sample_number'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
plot(b0['channel_number'])
ylabel('channel')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'channel')

# %%
print(b0.shape)
print(b0['data'].shape)
print(b0[0]['data'].shape)
# Out:
# (832,)
# (832, 1, 465, 2, 2)
# (1, 465, 2, 2)

# %%
d = b0['data']

# %%
figure()
imshow(d[:,0,:,0,0], aspect='auto', origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
plot(d[:,0,:,0,0].max(axis=0))
xlabel('Baseline')
ylabel('X pol')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'X pol')

# %%
nant = 30
idx = 0
products = []
revproducts = {}
auto_products = []
for a1 in range(1, nant+1):
    for a2 in range(a1, nant+1):
        print(f'{a1}-{a2}:{idx}')
        products.append((a1,a2))
        revproducts[(a1,a2)] = idx
        if a1 == a2:
            auto_products.append(idx)
            
        idx += 1
# Out:
# 1-1:0
# 1-2:1
# 1-3:2
# 1-4:3
# 1-5:4
# 1-6:5
# 1-7:6
# 1-8:7
# 1-9:8
# 1-10:9
# 1-11:10
# 1-12:11
# 1-13:12
# 1-14:13
# 1-15:14
# 1-16:15
# 1-17:16
# 22-23:421
# 22-24:422
# 22-25:423
# 22-26:424
# 22-27:425
# 22-28:426
# 22-29:427
# 22-30:428
# 23-23:429
# 23-24:430
# 23-25:431
# 23-26:432
# 23-27:433
# 23-28:434
# 23-29:435
# 23-30:436
# 24-24:437
# 24-25:438
# 24-26:439
# 24-27:440
# 24-28:441
# 24-29:442
# 24-30:443
# 25-25:444
# 25-26:445
# 25-27:446
# 25-28:447
# 25-29:448
# 25-30:449
# 26-26:450
# 26-27:451
# 26-28:452
# 26-29:453
# 26-30:454
# 27-27:455
# 27-28:456
# 27-29:457
# 27-30:458
# 28-28:459
# 28-29:460
# 28-30:461
# 29-29:462
# 29-30:463
# 30-30:464

# %%
products[3]
# Out:
# (1, 4)

# %%
revproducts[(1,4)]
# Out:
# 4

# %%
autos = list(filter(lambda bl: bl[0] == bl[1],products))

# %%
auto_products
# Out:
# [0,
#  30,
#  59,
#  87,
#  114,
#  140,
#  165,
#  189,
#  212,
#  234,
#  255,
#  275,
#  294,
#  312,
#  329,
#  345,
#  360,
#  374,
#  387,
#  399,
#  410,
#  420,
#  429,
#  437,
#  444,
#  450,
#  455,
#  459,
#  462,
#  464]

# %%
revproducts[(10,12)]
# Out:
# 236

# %%
d.shape
# Out:
# (832, 1, 465, 2, 2)

# %%
autos = d[:,0,auto_products,:,:]

# %%
autos.shape
# Out:
# (832, 30, 2, 2)

# %%
figure()
imshow(autos[:,:,0,0], aspect='auto', origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
b0.dtype
# Out:
# dtype([('frame_id', '<u8'), ('bat', '<u8'), ('beam_number', 'u1'), ('sample_number', 'u1'), ('channel_number', 'u1'), ('fpga_id', 'u1'), ('nprod', '<u2'), ('flags', 'u1'), ('zero1', 'u1'), ('version', '<u4'), ('zero3', '<u4'), ('data', '<i2', (1, 465, 2, 2))])

# %%
nblocks = autos.shape[0]//(4*64)
print(nblocks)
# Out:
# 0

# %%
np.prod((4, 64, 30, 2, 2))
# Out:
# 30720

# %%
autos = autos[:nblocks*64*4,...]
autos.shape
# Out:
# (768, 30, 2, 2)

# %%
## autos.shape = (nblocks, 4, 64, 30, 2, 2)
autos.shape #(block (time), channel, sample_nimber (time), antenna, pol, complex)
# Out:
# (3, 4, 64, 30, 2, 2)

# %%
np.transpose?

# %%
# new one will be (time, channel, antenna, pol, complex)
# do it 2 steps - transpose first, then merge 2 time axes with .shape

autost = np.transpose(autos, [0,2, 1, 3,4,5])

# %%
autost.shape
# Out:
# (3, 64, 4, 30, 2, 2)

# %%
# now merge the axes
autost = autost.reshape(3*64, 4, 30, 2, 2).astype(float)

# %%
autost.shape
# Out:
# (192, 4, 30, 2, 2)

# %%
figure()
imshow(autost[:,:,:,0,0].mean(axis=2).T, aspect='auto', origin='lower', interpolation='None')
xlabel('Sample number (x1.7ms)')
ylabel('Channel')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Channel')

# %%
90./1.7
# Out:
# 52.94117647058824

# %%
tsamp = 1.7 # milliseconds
dm = 67 # pc/cme
f1 = 0.9835
f2 = 0.9865
print(4.15*dm*(f1**-2 - f2**-2)) #milllseconds
print(4.15*dm*(f1**-2 - f2**-2)/tsamp) #samples
# Out:
# 1.7456914008178879
# 1.0268772945987577

# %%
figure()
plot(autost[:,:,:,:,0].mean(axis=2).T.mean(axis=0).mean(axis=0))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
autost.dtype
# Out:
# dtype('float64')

# %%
1/32
# Out:
# 0.03125

# %%
(16500-19000)/19000
# Out:
# -0.13157894736842105

# %%
autost.shape
# Out:
# (192, 4, 30, 2, 2)

# %%
figure()
plot(autost[:,0,:,0,0])
xlabel('sample number')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'sample number')

# %%
autost.shape
# Out:
# (192, 4, 30, 2, 2)

# %%
figure()
imshow(autost[:,0,:,0,0], aspect='auto', interpolation='none', origin='lower')
xlabel('Antno -1')
ylabel('sample for channel 0')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'sample for channel 0')

# %%
figure()
imshow(autost[:,1,:,0,0], aspect='auto', interpolation='none', origin='lower')
xlabel('Antno -1')
ylabel('sample for channel 1')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'sample for channel 1')

# %%
freqs = '983.5 983.519 983.537 983.556 983.574 983.593 983.611 983.63 983.648 984.5 984.519 984.537 984.556 984.574 984.593 984.611 984.63 984.648 985.5 985.519 985.537 985.556 985.574 985.593 985.611 985.63 985.648 986.5 986.519 986.537 986.556 986.574 986.593 986.611 986.63 986.648 983.667 983.685 983.704 983.722 983.741 983.759 983.778 983.796 983.815 984.667 984.685 984.704 984.722 984.741 984.759 984.778 984.796 984.815 985.667 985.685 985.704 985.722 985.741 985.759 985.778 985.796 985.815 986.667 986.685 986.704 986.722 986.741 986.759 986.778 986.796 986.815 983.833 983.852 983.87 983.889 983.907 983.926 983.944 983.963 983.981 984.833 984.852 984.87 984.889 984.907 984.926 984.944 984.963 984.981 985.833 985.852 985.87 985.889 985.907 985.926 985.944 985.963 985.981 986.833 986.852 986.87 986.889 986.907 986.926 986.944 986.963 986.981 984 984.019 984.037 984.056 984.074 984.093 984.111 984.13 984.148 985 985.019 985.037 985.056 985.074 985.093 985.111 985.13 985.148 986 986.019 986.037 986.056 986.074 986.093 986.111 986.13 986.148 987 987.019 987.037 987.056 987.074 987.093 987.111 987.13 987.148 984.167 984.185 984.204 984.222 984.241 984.259 984.278 984.296 984.315 985.167 985.185 985.204 985.222 985.241 985.259 985.278 985.296 985.315 986.167 986.185 986.204 986.222 986.241 986.259 986.278 986.296 986.315 987.167 987.185 987.204 987.222 987.241 987.259 987.278 987.296 987.315 984.333 984.352 984.37 984.389 984.407 984.426 984.444 984.463 984.481 985.333 985.352 985.37 985.389 985.407 985.426 985.444 985.463 985.481 986.333 986.352 986.37 986.389 986.407 986.426 986.444 986.463 986.481 987.333 987.352 987.37 987.389 987.407 987.426 987.444 987.463 987.481'.split()
freqs = np.array(list(map(float, freqs)))

# %%
figure()
plot(freqs)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
freqs.shape
# Out:
# (216,)

# %%
freqs.shape = (9,4,6)

# %%
freqs.mean(axis=2)
# Out:
# array([[983.5465    , 984.07416667, 984.602     , 985.5465    ],
#        [986.07416667, 986.602     , 983.713     , 984.24083333],
#        [984.7685    , 985.713     , 986.24083333, 986.7685    ],
#        [983.8795    , 984.40716667, 984.935     , 985.8795    ],
#        [986.40716667, 986.935     , 984.0465    , 984.57416667],
#        [985.102     , 986.0465    , 986.57416667, 987.102     ],
#        [984.213     , 984.74083333, 985.2685    , 986.213     ],
#        [986.74083333, 987.2685    , 984.3795    , 984.90716667],
#        [985.435     , 986.3795    , 986.90716667, 987.435     ]])
