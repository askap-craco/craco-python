# %%
import numpy as np
from pylab import *
from craco.cardcap import CardcapFile
from astropy.io import fits

# %matplotlib notebook

# %%
s = """
Antenna 0, max 1.0310891445963333e-05, rms 1.607145899007719e-06, S/N 6.415653645589654 
Antenna 1, max 6.600706144163787e-06, rms 9.057667144076499e-07, S/N 7.2874240565138155
Antenna 2, max 1.0133281978911655e-05, rms 1.962171748086358e-06, S/N 5.164319580482347
Antenna 3, max 5.386098496061061e-06, rms 8.698027153485261e-07, S/N 6.192322007069011
Antenna 4, max 5.427157132275003e-06, rms 9.761869366930814e-07, S/N 5.55954697638136
Antenna 5, max 5.989830405312211e-06, rms 1.0028659301072067e-06, S/N 5.97271302722578
Antenna 6, max 8.127900717096993e-06, rms 1.1519477361445818e-06, S/N 7.055789479043565
Antenna 7, max 5.013892971537318e-06, rms 7.839771179575e-07, S/N 6.395458306997584
Antenna 8, max 6.328541298107626e-06, rms 1.1061452990017934e-06, S/N 5.721256785902017
Antenna 9, max 6.652580830781909e-06, rms 1.0015784666616239e-06, S/N 6.64209650288881
Antenna 10, max 4.343088750145283e-06, rms 8.308059722658478e-07, S/N 5.227560820609445
Antenna 11, max 4.9858591711005e-06, rms 7.264707605427749e-07, S/N 6.86312435668487
"""

# %%
fmax = []
frms = []
fsn = []
for l in s.split('\n'):
    if l.strip() == '':
        continue
    bits = l.split(',')
    fmax.append(float(bits[1].split(' ')[2]))
    frms.append(float(bits[2].split(' ')[2]))
    fsn.append(float(bits[3].split(' ')[2]))

# %%
figure()
hist(fsn)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([2., 1., 1., 1., 1., 2., 1., 0., 2., 1.]),
#  array([5.16431958, 5.37663003, 5.58894048, 5.80125092, 6.01356137,
#         6.22587182, 6.43818227, 6.65049271, 6.86280316, 7.07511361,
#         7.28742406]),
#  <BarContainer object of 10 artists>)

# %%
figure()
hist(frms)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([3., 2., 3., 2., 0., 0., 0., 1., 0., 1.]),
#  array([7.26470761e-07, 8.50040859e-07, 9.73610958e-07, 1.09718106e-06,
#         1.22075116e-06, 1.34432125e-06, 1.46789135e-06, 1.59146145e-06,
#         1.71503155e-06, 1.83860165e-06, 1.96217175e-06]),
#  <BarContainer object of 10 artists>)

# %%
figure()
hist(fmax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1., 4., 1., 3., 0., 0., 1., 0., 0., 2.]),
#  array([4.34308875e-06, 4.93986902e-06, 5.53664929e-06, 6.13342956e-06,
#         6.73020983e-06, 7.32699010e-06, 7.92377037e-06, 8.52055064e-06,
#         9.11733091e-06, 9.71411118e-06, 1.03108914e-05]),
#  <BarContainer object of 10 artists>)

# %%
figure()
scatter(fmax, frms)
for i in range(len(fmax)):
    text(fmax[i], frms[i], f'Ant {i}')
xlabel('Max')
ylabel('RMS')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'RMS')
