# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
from craft import uvfits, craco, craco_plan
from craco import preprocess

# %%
from sigpyproc.readers import FilReader as F

# %%
casfname = "/data/seren-03/big/craco/SB051893/scans/00/20230808190740/results/cas_b02.fil"
f = F(casfname)

# %%
f.header
# Out:
# Header(filename='/data/seren-03/big/craco/SB051893/scans/00/20230808190740/results/cas_b02.fil', data_type='filterbank', nchans=720, foff=0.1666666666666664, fch1=855.574074074074, nbits=32, tsamp=0.110592, tstart=60164.797226671086, nsamples=64513, nifs=1, coord=<SkyCoord (ICRS): (ra, dec) in deg
#     (331.54396253, 0.52497794)>, azimuth=<Angle 0. deg>, zenith=<Angle 0. deg>, telescope='Fake', backend='FAKE', source='FLASH_578', frame='topocentric', ibeam=0, nbeams=0, dm=0, period=0, accel=0, signed=False, rawdatafile='', hdrlens=[202], datalens=[185797440], filenames=['/data/seren-03/big/craco/SB051893/scans/00/20230808190740/results/cas_b02.fil'], nsamples_files=[64513], tstart_files=[60164.797226671086])

# %%
start_reading = 2200   #s
read_for = 300   #s

# %%
fullblock = f.read_block(int(start_reading / f.header.tsamp), int(read_for / f.header.tsamp))

# %%
fullblock.shape
# Out:
# (720, 2712)

# %%
plt.figure()
plt.imshow(fullblock, aspect='auto', interpolation='None', origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
2712 / 32
# Out:
# 84.75

# %%
32 * 84 * f.header.tsamp
# Out:
# 297.271296
