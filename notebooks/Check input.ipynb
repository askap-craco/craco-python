# %%
import numpy as np
from pylab import *
       
# %matplotlib notebook

from craco import calibration
# %load_ext autoreload
# %autoreload 2
from scipy.interpolate import interp1d

# %%
fin = '/data/big/craco/SB048709/scans/00/20230303003206/results/maxn30/input_iblk0.npy'

d = np.load(fin, allow_pickle=True)

# %%
d.shape
# Out:
# (136, 80, 256)

# %%
d.dtype
# Out:
# dtype('complex64')

# %%
figure()
imshow(d.real.mean(axis=0).T.data)
# Out:
# <img src="data:image/png;base64,..." width="640">
