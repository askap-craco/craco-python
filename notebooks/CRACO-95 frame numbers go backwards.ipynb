# %%
import numpy as np
from pylab import *
from craco.cardcap import CardcapFile
from astropy.io import fits
import glob

# %matplotlib notebook

# %%
dstr = '/data/craco/ban115/craco-python/notebooks/data/SB43350/multirun-dp/run1*.fits'
cc = [CardcapFile(f) for f in glob.glob(dstr)]

# %%
pkts = [c.load_packets(count=1000) for c in cc]

# %%
figure()
for pkt in pkts:
    plot(pkt['frame_id']-88400000,'x')
# Out:
# <img src="data:image/png;base64,..." width="640">
