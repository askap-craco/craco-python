# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0, 1, (100, 10000))
x[:, 50] = 10

# %%
siny = (np.sin(np.arange(100)/1.55) /10 + 1)
expy = np.exp(-1*np.arange(100)/100)
expy += 1 - np.mean(expy)

# %%
plt.figure()
plt.plot((expy + siny)/2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x2 = x.copy()
for ii in range(len(x)):
    x2[ii] = x[ii] * (expy[ii] + siny[ii])/2

# %%
np.std(x2.ravel()), np.std(x.ravel())
# Out:
# (1.0105327170181455, 1.004846169541016)

# %%
plt.figure()
plt.plot(np.std(x, axis=-1))
plt.plot(np.std(x2, axis=-1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.imshow(x2[:, :500], aspect='auto')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ts = x.sum(axis=0)
ts2 = x2.sum(axis=0)

# %%
ts[50] / ts[51:].std(), ts2[50] / ts2[51:].std(), ts[50] / np.sqrt(x.shape[0]), ts2[50] / np.sqrt(x.shape[0])
# Out:
# (99.16601915497924, 98.66804034106761, 100.0, 100.05842306714611)

# %%
ts[50:].std()
# Out:
# 14.185345954332213

# %%
x.shape
# Out:
# (100, 10000)

# %%
x2.shape
# Out:
# (100, 10000)

# %%
t = np.random.normal(0, 1, (100, 10000))
t.std()
# Out:
# 0.9998481927133038

# %%
t.sum(axis=0).std()
# Out:
# 9.999788022950908

# %%
x[:, 50:].std()
# Out:
# 1.0050002965047258

# %%
x.sum(axis=0)[50:].std()
# Out:
# 14.185345954332213

# %%
x.shape
# Out:
# (100, 10000)

# %%
x.sum(axis=0).shape
# Out:
# (10000,)

# %%
plt.figure()
plt.plot(x.sum(axis=0))
plt.plot(ts)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
d = np.random.normal(0, 1, 20000).reshape(2, 10000)
d[1] *= 1.5
d[:, 10] = 10

raw_sum = np.sum(d, axis=0) / 2
std_weighted_sum = d[0] + d[1]/d[1].std()  / np.sqrt(1**2 + d[1].std()**2)
var_weighted_sum = d[0] + d[1]/d[1].std()**2 / np.sqrt(1**4 + d[1].std()**4)

raw_sum[10]/raw_sum[11:].std(), std_weighted_sum[10]/std_weighted_sum[11:].std(), var_weighted_sum[10]/var_weighted_sum[11:].std()
# Out:
# (11.141095746254027, 12.071901366749058, 11.461547071561181)
