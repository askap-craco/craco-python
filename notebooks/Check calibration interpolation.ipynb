# %%
import numpy as np
from pylab import *
       
# %matplotlib notebook

from craco import calibration
# %load_ext autoreload
# %autoreload 2
from scipy.interpolate import interp1d
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cal='/data/seren-10/big/craco/results/SB048712/scans/00/20230303015705/cal/output_beam00.uvfits.mir'

# %%
g,freqs = calibration.load_gains(cal)
# Out:
# Using MIRIAD bandpass solutions
# /data/seren-01/fast/ban115/build/craft/src/craft/craftcor.py:711: UserWarning: MiriadSolution can only handle 1 time step
#   warnings.warn('MiriadSolution can only handle 1 time step')
# /data/seren-01/fast/ban115/build/craco-python/src/craco/calibration.py:109: UserWarning: Miraid gain solutions for /data/seren-10/big/craco/results/SB048712/scans/00/20230303015705/cal/output_beam00.uvfits.mir contain 2 solutions. Just taking average
#   warnings.warn(f'Miraid gain solutions for {fname} contain {ntimes} solutions. Just taking average')

# %%
g.shape
# Out:
# (36, 1680, 1)

# %%
freqs.shape
# Out:
# (1680,)

# %%
to_freqs = freqs[300:700]
ig = calibration.interpolate_gains(g,freqs,to_freqs)

# %%
figure()
plot(freqs, g[0,:,0])
plot(to_freqs,ig[0,:,0],'x')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /data/seren-01/fast/ban115/build/venv/lib/python3.7/site-packages/numpy/ma/core.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   fill_value = np.array(fill_value, copy=False, dtype=ndtype)
# /data/seren-01/fast/ban115/build/venv/lib/python3.7/site-packages/numpy/ma/core.py:2830: ComplexWarning: Casting complex values to real discards the imaginary part
#   order=order, subok=True, ndmin=ndmin)
# /data/seren-01/fast/ban115/build/venv/lib/python3.7/site-packages/numpy/ma/core.py:2830: ComplexWarning: Casting complex values to real discards the imaginary part
#   order=order, subok=True, ndmin=ndmin)
