# %%
import numpy as np
from pylab import *
from craft import sigproc
# %matplotlib notebook

# %%
cd /data/craco/ban115/craco-python/notebooks/data/vela/SB43350/multirun-dp
# Out:
# /data/craco/ban115/craco-python/notebooks/data/SB43350/multirun-dp

# %%
fin = sigproc.SigprocFile('run4cas.fil')
# Out:
# telescope_id None
# machine_id None
# data_type None
# barycentric None
# pulsarcentric None
# nbits 32
# nsamples None
# nchans 288
# nifs 1
# /data/craco/ban115/craft-github/src/craft/sigproc.py:62: UserWarning: Could not find parameter telescope_id
#   warnings.warn('Could not find parameter {}'.format(param))
# /data/craco/ban115/craft-github/src/craft/sigproc.py:62: UserWarning: Could not find parameter machine_id
#   warnings.warn('Could not find parameter {}'.format(param))
# /data/craco/ban115/craft-github/src/craft/sigproc.py:62: UserWarning: Could not find parameter data_type
#   warnings.warn('Could not find parameter {}'.format(param))
# /data/craco/ban115/craft-github/src/craft/sigproc.py:62: UserWarning: Could not find parameter barycentric
#   warnings.warn('Could not find parameter {}'.format(param))
# /data/craco/ban115/craft-github/src/craft/sigproc.py:62: UserWarning: Could not find parameter pulsarcentric
# ...

# %%
d = np.fromfile(fin.fin, dtype=np.float32)
d = d.reshape(-1,288)
d.shape
# Out:
# (6400, 288)

# %%
fin.tsamp
# Out:
# 0.001728

# %%
period = 89e-3

# %%
nbins = int(np.round(period/fin.tsamp))
nbins
# Out:
# 52

# %%
d -= d.mean(axis=0, keepdims=True)

# %%
nt = d.shape[0]
nint = nt // nbins

# %%
d = d[:nint*nbins,:].reshape(nint,nbins,-1)
d.shape
# Out:
# (123, 52, 288)

# %%
x = d.mean(axis=0)
x.shape
# Out:
# (52, 288)

# %%
figure()
imshow(x.T, aspect='auto')
# Out:
# <img src="data:image/png;base64,..." width="640">
