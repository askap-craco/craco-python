# %%
# %matplotlib inline
from pylab import *
import numpy as np
from craco.search_pipeline import location2pix, get_grid_lut_from_plan, grid_candidates,wait_for_starts,waitall,print_candidates
import craco
import craco.search_pipeline
from craco.pyxrtutil import *
import craft.craco_plan

from craft import uvfits

from craft.craco_plan import PipelinePlan

# %%
fits='/data/craco/ban115/test_data/frb_d0_t0_a1_sninf_lm00/frb_d0_t0_a1_sninf_lm00.fits'
f = uvfits.open(fits)
plan = PipelinePlan(f, "--ndm 2")
# Out:
# parsing values --ndm 2

# %%
b = f.baselines

# %%
tab = f.hdulist[0]

# %%
tab.header
# Out:
# SIMPLE  =                    T  /
# BITPIX  =                  -32  /
# NAXIS   =                    6  /
# NAXIS1  =                    0  /
# NAXIS2  =                    3  /
# NAXIS3  =                    1  /
# NAXIS4  =                  256  /
# NAXIS5  =                    1  /
# NAXIS6  =                    1  /
# EXTEND  =                    T  /
# GROUPS  =                    T  /
# PCOUNT  =                    5  /
# GCOUNT  =                 3230  /
# BSCALE  =    1.00000000000E+00  /
# BZERO   =    0.00000000000E+00  /
# DATE-OBS= '2020-06-09T00:00:00.0'  /
# PTYPE1  = 'UU      '  /
# PSCAL1  =    1.00000000000E+00  /
# PZERO1  =    0.00000000000E+00  /
# PTYPE2  = 'VV      '  /
# PSCAL2  =    1.00000000000E+00  /
# PZERO2  =    0.00000000000E+00  /
# PTYPE3  = 'WW      '  /
# PSCAL3  =    1.00000000000E+00  /
# PZERO3  =    0.00000000000E+00  /
# PTYPE4  = 'BASELINE'  /
# PSCAL4  =    1.00000000000E+00  /
# PZERO4  =    0.00000000000E+00  /
# PTYPE5  = 'DATE    '  /
# PSCAL5  =    1.00000000000E+00  /
# PZERO5  =    2.45900950000E+06  /
# CRPIX2  =    1.00000000000E+00  /
# CDELT2  =    1.00000000000E+00  /
# CRVAL2  =    1.00000000000E+00  /
# CTYPE2  = 'COMPLEX '  /
# CRPIX3  =    1.00000000000E+00  /
# CDELT3  =    1.00000000000E+00  /
# CRVAL3  =    1.00000000000E+00  /
# CTYPE3  = 'STOKES  '  /
# CRPIX4  =    1.00000000000E+00  /
# CDELT4  =    1.00000004750E+06  /
# CRVAL4  =    7.35499993944E+08  /
# CTYPE4  = 'FREQ    '  /
# CRPIX5  =    1.00000000000E+00  /
# CDELT5  =    1.00000000000E+00  /
# CRVAL5  =    0.00000000000E+00  /
# CTYPE5  = 'RA      '  /
# CRPIX6  =    1.00000000000E+00  /
# CDELT6  =    1.00000000000E+00  /
# CRVAL6  =   -3.00000000000E+01  /
# CTYPE6  = 'DEC     '  /
# OBJECT  = 'frb_d0_t0_a1_sni'  /
# OBSRA   =    0.00000000000E+00  /
# OBSDEC  =   -3.00000000000E+01  /
# EPOCH   =    2.00000000000E+03  /
# RESTFREQ=    8.63000000000E+08  /
# VELREF  =                  257  /
# ALTRPIX =    1.00000000000E+00  /
# ALTRVAL =    4.42914720000E+07  /
# TELESCOP= 'ASKAP   '  /
# INSTRUME= 'ASKAP   '  /
# ORIGIN  = 'Miriad fits: Revision 1.34, 2019/08/04 23:07:40 UTC'  /
# HISTORY UVGEN: Miriad Uvgen: $Revision: 1.12 $, $Date: 2020/04/15 08:11:34 $
# HISTORY UVGEN: Executed on: 2020-09-17T18:31:40.0
# HISTORY UVGEN: Command line inputs follow:
# HISTORY UVGEN:   stokes=I
# HISTORY UVGEN:   baseunit=3.33564
# HISTORY UVGEN:   harange=0.000000,0.000008
# HISTORY UVGEN:   telescop=askap
# HISTORY UVGEN:   inttime=0.001728
# HISTORY UVGEN:   ant=/data/craco/ban115/craft/python/askap-ak1-ak20.ant
# HISTORY UVGEN:   source=frb_d0_t0_a1_sninf_lm00.fits.frbpos
# HISTORY UVGEN:   radec=0,-30
# HISTORY UVGEN:   corr=256,1,0,256.0
# HISTORY UVGEN:   time=20JUN10:00:00:00
# HISTORY UVGEN:   lat=-26.679
# HISTORY UVGEN:   freq=0.863,0.256
# HISTORY UVGEN:   out=frb_d0_t0_a1_sninf_lm00.fits.mir
# HISTORY
# HISTORY UVGEN: Source specifications:
# HISTORY UVGEN:      Flux     RA      DEC    Major  Minor    Axis    Pol-I  Pol-P
# HISTORY UVGEN:      (Jy)     (")     (")     (")    (")     (deg)    (%)    (deg
# HISTORY UVGEN:  1   1.00     0.0     0.0    0.00    0.00     0.0     0.0    0.00
# HISTORY UVGEN: Antenna positions :
# HISTORY UVGEN: Correlator freq:    0.00
# HISTORY UVGEN: Correlator band:  256.00
# HISTORY UVGEN: Line/continuum:   0.000000 center:   0.000000, width:   0.000000
# HISTORY UVGEN: Channels:  256   Spectra:    1   Wideband:    1
# HISTORY UVGEN: Tsys(K):     0.  Tsky(K):     0.  tau(zenith):   0.00
# HISTORY UVGEN: Wide widths (MHz):  256.000
# HISTORY UVGEN: Wide noise   (Jy):    0.000
# HISTORY UVGEN: Channel widths (MHz):    1.000
# HISTORY UVGEN: Channel noise   (Jy):    0.000
# HISTORY UVGEN: 3230 records written to file: frb_d0_t0_a1_sninf_lm00.fits.mir
# HISTORY FITS: Miriad fits: fits: Revision 1.34, 2019/08/04 23:07:40 UTC
# HISTORY FITS: Executed on: 20SEP17:18:31:41.0
# HISTORY FITS: Command line inputs follow:
# HISTORY FITS:    op=uvout
# HISTORY FITS:    in=frb_d0_t0_a1_sninf_lm00.fits.mir
# HISTORY FITS:    out=frb_d0_t0_a1_sninf_lm00.fits
# HISTORY FITS: NOTE: Use options=varwt if loading into Miriad
# HISTORY AIPS WTSCAL =  1.00000000000E+00

# %%
d = tab.data

# %%
d.columns
# Out:
# ColDefs(
#     name = 'UU'; format = 'E'; bscale = 1.0; bzero = 0.0
#     name = 'VV'; format = 'E'; bscale = 1.0; bzero = 0.0
#     name = 'WW'; format = 'E'; bscale = 1.0; bzero = 0.0
#     name = 'BASELINE'; format = 'E'; bscale = 1.0; bzero = 0.0
#     name = 'DATE'; format = 'E'; bscale = 1.0; bzero = 2459009.5
#     name = 'DATA'; format = '768E'; bscale = 1.0; dim = (1, 1, 256, 1, 3)
# )

# %%
d[0]['UU']
# Out:
# 3.9145483e-08

# %%
d[0]['VV']
# Out:
# 1.19109195e-07

# %%
d[0]['WW']
# Out:
# 9.108906e-08

# %%
d[0]['BASELINE']
# Out:
# 258.0

# %%
d[0]['DATE']
# Out:
# 2459010.5

# %%
d[0]['DATA']
# Out:
# array([[[[[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]],
#
#          [[1.      , 0.      , 0.001728]]]]], dtype=float32)

# %%
len(d)
# Out:
# 3230

# %%
plan

# %%
dir(plan)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'baseline_order',
#  'baseline_shape',
#  'baselines',
#  'boxcar_weight',
#  'dmax',
#  'dtype',
#  'fdmt_plan',
#  'fdmt_scale',
#  'fft_scale',
#  'fft_ssr',
#  'fmax',
#  'fmin',
#  'foff',
#  'freqs',
#  'get_uv',
#  'lower_idxs',
#  'lower_instructions',
#  'lower_shifts',
#  'nbl',
#  'nbox',
#  'nchunk_time',
#  'ncin',
#  'ncu',
#  'nd',
#  'ndout',
#  'nf',
#  'ngridreg',
#  'npix',
#  'nt',
#  'nuvmax',
#  'nuvrest',
#  'nuvrest_max',
#  'nuvwide',
#  'save_fdmt_plan_lut',
#  'save_grid_instructions',
#  'save_lut',
#  'save_pad_lut',
#  'threshold',
#  'upper_idxs',
#  'upper_instructions',
#  'upper_shifts',
#  'uv_shape',
#  'uvcells',
#  'values']

# %%
plan.ff
