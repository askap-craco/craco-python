# %%
import numpy as np
from pylab import *
from craco.metadatafile import MetadataFile
# %matplotlib notebook

# %%
f = MetadataFile('SB47619.json.gz')

# %%
f.antnames
# Out:
# ['ak01',
#  'ak02',
#  'ak03',
#  'ak04',
#  'ak05',
#  'ak06',
#  'ak07',
#  'ak08',
#  'ak09',
#  'ak10',
#  'ak11',
#  'ak12',
#  'ak13',
#  'ak14',
#  'ak15',
#  'ak16',
#  'ak17',
#  'ak18',
#  'ak19',
#  'ak20',
#  'ak21',
#  'ak22',
#  'ak23',
#  'ak24',
#  'ak25',
#  'ak26',
#  'ak27',
#  'ak28',
#  'ak29',
#  'ak30',
#  'ak31',
#  'ak32',
#  'ak33',
#  'ak34',
#  'ak35',
#  'ak36']

# %%
f.time_floats.min()
# Out:
# 59978.91315315183

# %%
f.time_floats.max()
# Out:
# 59979.00554355184

# %%
f.all_uvw.shape
# Out:
# (803, 36, 36, 3)

# %%
plot(f.all_uvw[:,0,0,0])
title('U')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'U')

# %%
t = 29
beam = 1

# %%
uvw = f.all_uvw[t, :, 0:2, :]

# %%
uvw.shape
# Out:
# (36, 2, 3)

# %%
uvw[1,:,:] - uvw[0,:,:]
# Out:
# array([[13.29516997, 16.14502871, 21.46973266],
#        [12.60174104, 16.75633785, 21.41948136]])
